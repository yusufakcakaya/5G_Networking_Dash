# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Deman Driven Postalcode Data Results

# %%
df = pd.read_csv('data/supply_driven_analysis_results.csv')

# %%
df
# Out:
#      Unnamed: 0               scenario              strategy  geotype  \
# 0             1   Scenario 1 (30 Mbps)                Hybrid  Rural 1
# 1             2  Scenario 2 (100 Mbps)                Hybrid  Rural 1
# 2             3  Scenario 3 (300 Mbps)           Small Cells  Rural 1
# 3             4  Scenario 3 (300 Mbps)                Hybrid  Rural 1
# 4             5  Scenario 2 (100 Mbps)           Small Cells  Rural 1
# ..          ...                    ...                   ...      ...
# 121         122  Scenario 3 (300 Mbps)                Hybrid    Urban
# 122         123  Scenario 2 (100 Mbps)           Small Cells    Urban
# 123         124  Scenario 2 (100 Mbps)                Hybrid    Urban
# 124         125  Scenario 2 (100 Mbps)  Spectrum Integration    Urban
# 125         126  Scenario 3 (300 Mbps)  Spectrum Integration    Urban
#
#     spectrum_availability  pop_density_km2  user_speed_mbps  active_users  \
# 0                     All          1176.48               30          5.58
# 1                     All          1176.48              100          5.58
# 2                     All          1176.48              300          5.58
# 3                     All          1176.48              300          5.58
# 4                     All          1176.48              100          5.58
# ..                    ...              ...              ...           ...
# 121               Limited          9520.01              300         45.12
# 122               Limited          9520.01              100         45.12
# 123               Limited          9520.01              100         45.12
# 124               Limited          9520.01              100         45.12
# 125               Limited          9520.01              300         45.12
#
#      demand_mbps_km2  max_user_demand_lte_mbps_km2  \
# 0             167.30                         10.97
# 1             557.66                         10.97
# 2            1672.98                         10.97
# 3            1672.98                         10.97
# 4             557.66                         10.97
# ..               ...                           ...
# 121         13537.44                         11.20
# 122          4512.48                         11.20
# 123          4512.48                         11.20
# 124          4512.48                         11.20
# 125         13537.44                         11.20
#
#      max_user_demand_5g_mbps_km2  max_user_demand_total_mbps_km2
# 0                           4.08                           15.05
# 1                           4.08                           15.05
# 2                           0.00                           10.97
# 3                           4.08                           15.05
# 4                           0.00                           10.97
# ..                           ...                             ...
# 121                         4.11                           15.31
# 122                         0.00                           11.20
# 123                         4.11                           15.31
# 124                         4.11                           15.31
# 125                         4.11                           15.31
#
# [126 rows x 12 columns]
